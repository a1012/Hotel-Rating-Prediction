# %%
#Import Dependencies
import os, json
import pandas as pd
import csv
from pandas.io.json import json_normalize
import re
import csv

# %%
#To finds  json files
path_to_json = 'C:/Users/ayu_a/Downloads/json/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files[0])
# Out:
# 100407.json

# %%
#Function to check  whether Name,Price and Address of Hotel is present
def validate_json_keys(json):
    if 'Name' not in json.keys():
        print("key : Name is not present")
        return False
    if 'Price' not in json.keys():
        print("key : Price is not present")
        return False
    if 'Address' not in json.keys():
        print("key : Price is not present")
        return False
    
    return True

# %%
# we need both the json and an index number so use enumerate()
name =[]
price = []
address=[]
reviews=[]
authors=[]
a_location =[]
Content=[]
title=[]


for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)
        hotelname=json_text["HotelInfo"]
        if validate_json_keys(hotelname):
            hotel_name = hotelname['Name']
            prices =hotelname['Price']
            hotel_address = hotelname['Address']
            hotel_address = re.sub('<[^>]*>',"",hotel_address.rstrip().lstrip())
            review_list = json_text["Reviews"]
            for review in review_list:
                name.append(hotel_name)
                price.append(prices)
                address.append(hotel_address)
                reviews.append(review['Ratings'])
                authors.append(review['Author'])
                a_location.append(review['AuthorLocation'] )
                Content.append(review['Content'])
                title.append(review['Title']) 
            
        else:
            print(">>Error in JSON data text.\n",)
# Out:
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# ...
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.
#
# key : Name is not present
# >>Error in JSON data text.

# %%
temp={"HotelName":name,"HotelPrice":price,"HotelAddress":address,"HotelRatings":reviews,"AuthorName":authors,
     "Authorlocation":a_location,"Review":Content,"title":title}

# %%
#Converting Dictionary to Dataframe.
df = pd.DataFrame.from_dict(temp)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1476839 entries, 0 to 1476838
# Data columns (total 8 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   HotelName       1476839 non-null  object
#  1   HotelPrice      1476839 non-null  object
#  2   HotelAddress    1476839 non-null  object
#  3   HotelRatings    1476839 non-null  object
#  4   AuthorName      1476839 non-null  object
#  5   Authorlocation  1476839 non-null  object
#  6   Review          1476839 non-null  object
#  7   title           1476839 non-null  object
# dtypes: object(8)
# memory usage: 90.1+ MB

# %%
df.head(5)
# Out:
#                                  HotelName    HotelPrice  \
# 0  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 1  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 2  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 3  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 4  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
#
#                                HotelAddress  \
# 0  5015 Campbell Blvd, Baltimore, MD 21236
# 1  5015 Campbell Blvd, Baltimore, MD 21236
# 2  5015 Campbell Blvd, Baltimore, MD 21236
# 3  5015 Campbell Blvd, Baltimore, MD 21236
# 4  5015 Campbell Blvd, Baltimore, MD 21236
#
#                                         HotelRatings    AuthorName  \
# 0  {'Service': '5', 'Cleanliness': '5', 'Overall'...      Nadine R
# 1  {'Service': '4', 'Cleanliness': '4', 'Overall'...       blt3116
# 2  {'Service': '5', 'Cleanliness': '5', 'Overall'...       ExSpec5
# 3  {'Service': '5', 'Cleanliness': '5', 'Overall'...   kevinlynch3
# 4  {'Service': '5', 'Cleanliness': '5', 'Overall'...  nobumponalog
#
#           Authorlocation                                             Review  \
# 0  Jacksonville, Florida  Usually stay near the airport, but this trip w...
# 1      Chillicothe, Ohio  Stayed at this Hilton for 2 nights. It was lik...
# 2      Northern Virginia  Stayed there one night, December 16, on the wa...
# 3                Raleigh  I just stayed here last weekend and have alrea...
# 4            Belmont, MA  My mother who is 90 and I stayed one night on ...
#
#                                       title
# 0                “Great place and location”
# 1            “Nice stay, nice surroundings”
# 2  “Perfect for an overnight just off I-95”
# 3                             “Great Hotel”
# 4        “good room for handicapped person”

# %%
#To viiew some basic statistical details
df['HotelName'].describe()
# Out:
# count                1476839
# unique                  7840
# top       Bellagio Las Vegas
# freq                    9714
# Name: HotelName, dtype: object

# %%
ratings=df['HotelRatings'].apply(pd.Series)

# %%
df.head(5)
# Out:
#                                  HotelName    HotelPrice  \
# 0  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 1  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 2  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 3  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
# 4  Hilton Garden Inn Baltimore White Marsh  $135 - $193*
#
#                                HotelAddress  \
# 0  5015 Campbell Blvd, Baltimore, MD 21236
# 1  5015 Campbell Blvd, Baltimore, MD 21236
# 2  5015 Campbell Blvd, Baltimore, MD 21236
# 3  5015 Campbell Blvd, Baltimore, MD 21236
# 4  5015 Campbell Blvd, Baltimore, MD 21236
#
#                                         HotelRatings    AuthorName  \
# 0  {'Service': '5', 'Cleanliness': '5', 'Overall'...      Nadine R
# 1  {'Service': '4', 'Cleanliness': '4', 'Overall'...       blt3116
# 2  {'Service': '5', 'Cleanliness': '5', 'Overall'...       ExSpec5
# 3  {'Service': '5', 'Cleanliness': '5', 'Overall'...   kevinlynch3
# 4  {'Service': '5', 'Cleanliness': '5', 'Overall'...  nobumponalog
#
#           Authorlocation                                             Review  \
# 0  Jacksonville, Florida  Usually stay near the airport, but this trip w...
# 1      Chillicothe, Ohio  Stayed at this Hilton for 2 nights. It was lik...
# 2      Northern Virginia  Stayed there one night, December 16, on the wa...
# 3                Raleigh  I just stayed here last weekend and have alrea...
# 4            Belmont, MA  My mother who is 90 and I stayed one night on ...
#
#                                       title
# 0                “Great place and location”
# 1            “Nice stay, nice surroundings”
# 2  “Perfect for an overnight just off I-95”
# 3                             “Great Hotel”
# 4        “good room for handicapped person”

# %%
concat_df=pd.concat([df,ratings],axis=1)

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1476839 entries, 0 to 1476838
# Data columns (total 17 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   HotelName                                 1476839 non-null  object
#  1   HotelPrice                                1476839 non-null  object
#  2   HotelAddress                              1476839 non-null  object
#  3   HotelRatings                              1476839 non-null  object
#  4   AuthorName                                1476839 non-null  object
#  5   Authorlocation                            1476839 non-null  object
#  6   Review                                    1476839 non-null  object
#  7   title                                     1476839 non-null  object
#  8   Service                                   1343123 non-null  object
#  9   Cleanliness                               1341250 non-null  object
#  10  Overall                                   1476839 non-null  object
#  11  Value                                     1343485 non-null  object
#  12  Sleep Quality                             768738 non-null   object
#  13  Rooms                                     1214348 non-null  object
#  14  Location                                  1143490 non-null  object
#  15  Business service (e.g., internet access)  158021 non-null   object
#  16  Check in / front desk                     258100 non-null   object
# dtypes: object(17)
# memory usage: 191.5+ MB

# %%
#To convert dataframe to CSV Format
concat_df.to_csv('concated.csv')
